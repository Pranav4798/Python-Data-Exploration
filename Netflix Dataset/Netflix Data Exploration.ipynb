# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('file.csv')

# %% [markdown]
# ### Data Exploration

# %%
df.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail(5)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.describe()
# Out:
#        Show_Id Category              Title                Director  \
# count     7789     7789               7789                    5401
# unique    7787        2               7787                    4050
# top      s6621    Movie  The Lost Okoroshi  Raúl Campos, Jan Suter
# freq         2     5379                  2                      18
#
#                       Cast        Country     Release_Date Rating  Duration  \
# count                 7071           7282             7779   7782      7789
# unique                6831            681             1565     14       216
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    18           2556              118   2865      1608
#
#                  Type                                        Description
# count            7789                                               7789
# unique            492                                               7769
# ...

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.count()
# Out:
# Show_Id         7789
# Category        7789
# Title           7789
# Director        5401
# Cast            7071
# Country         7282
# Release_Date    7779
# Rating          7782
# Duration        7789
# Type            7789
# Description     7789
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df['Title'].unique
# Out:
# <bound method Series.unique of 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7789, dtype: object>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Tasks

# %% [markdown]
# #### Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# #### Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns
# Out:
# C:\Users\Pranav\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# ### Questions

# %% [markdown]
# #### Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
df[df['Title'] == 'House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
dq = df[df['Title'].isin(['House of Cards'])]
dq
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
print('Show ID is {} and directors are {}'.format(dq['Show_Id'].iloc[0],dq['Director'].iloc[0]))
# Out:
# Show ID is s2833 and directors are Robin Wright, David Fincher, Gerald McRaney, John David Coles, David Manson

# %% [markdown]
# #### Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
df['Date_Y'] = pd.to_datetime(df['Release_Date'])

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_Y
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
df['Date_Y'].dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_Y, dtype: int64

# %%
df['Date_Y'].dt.year.value_counts().plot(kind='bar')

# %% [markdown]
# #### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(df['Category'])

# %%
df.groupby('Category').Category.count().plot(kind='bar')

# %% [markdown]
# #### Q. 4) Show all the Movies that were released in year 2020.

# %%
df['Year'] = df['Date_Y'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_Y    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df4 = df[(df['Category'] == 'Movie') & (df['Year'] == 2020)]
df4.head(5)
# Out:
#    Show_Id Category                          Title  \
# 4       s5    Movie                             21
# 6       s7    Movie                            122
# 14     s15    Movie                           3022
# 27     s28    Movie                         #Alive
# 28     s29    Movie  #AnneFrank - Parallel Stories
#
#                        Director  \
# 4                Robert Luketic
# 6               Yasir Al Yasiri
# 14                   John Suits
# 27                       Cho Il
# 28  Sabina Fedeli, Anna Migotto
#
#                                                  Cast        Country  \
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
# 27                           Yoo Ah-in, Park Shin-hye    South Korea
# 28                        Helen Mirren, Gengher Gatti          Italy
#
# ...

# %%
print('Number of movies released in 2020 were', len(df4))
# Out:
# Number of movies released in 2020 were 1313

# %% [markdown]
# #### Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df['Title'][(df['Country'].isin(['India'])) & (df['Category'] == 'TV Show')]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# #### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Johnnie To                 8
# Name: Director, dtype: int64

# %% [markdown]
# #### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df7 = df[(((df['Category'] == 'Movie') & (df['Type'].isin(['Comedies']))) | (df['Country'].isin(['United Kingdom'])))]
df7.head(5)
# Out:
#    Show_Id Category                Title          Director  \
# 19     s20    Movie                  '89               NaN
# 33     s34    Movie         #realityhigh  Fernando Lebrija
# 58     s59  TV Show          100% Hotter               NaN
# 72     s73    Movie             17 Again       Burr Steers
# 82     s83    Movie  2036 Origin Unknown     Hasraf Dulull
#
#                                                  Cast         Country  \
# 19                 Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# 58  Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
# 72  Zac Efron, Leslie Mann, Matthew Perry, Thomas ...   United States
# 82  Katee Sackhoff, Ray Fearon, Julie Cox, Steven ...  United Kingdom
#
#          Release_Date Rating  Duration  \
# 19       May 16, 2018  TV-PG    87 min
# 33  September 8, 2017  TV-14    99 min
# 58   November 1, 2019  TV-14  1 Season
# ...

# %%
print("Number of titles for when 'Category is Movie and Type is Comedies' or 'Country is United Kingdom' are", len(df7))
# Out:
# Number of titles for when 'Category is Movie and Type is Comedies' or 'Country is United Kingdom' are 485

# %% [markdown]
# #### Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_Y    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
dnull = df.dropna()

# %%
dnull[dnull['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_Y    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# #### Q. 9) What are the different Ratings defined by Netflix ?

# %%
df['Rating'].value_counts()
# Out:
# TV-MA       2865
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %% [markdown]
# #### Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
(df['Country'].str.contains('Canada') & (df['Rating'] == 'TV-14')).sum()
# Out:
# 47

# %% [markdown]
# #### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
((df['Rating'] == 'R') & (df['Year'] > 2018)).sum()
# Out:
# 450

# %% [markdown]
# #### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
max(df['Duration'])
# Out:
# '99 min'

# %%
df['Time_Min'] = df['Duration'].str.split(" ", expand=True)[0]

# %%
#df = df.drop('Time_Min', axis=1)
#df = df.drop(df.columns[-1],axis=1)

# %%
df.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Time_Min'] = df['Time_Min'].astype(int)

# %%
df10 = df['Title'][max(df['Time_Min'])]
df10
# Out:
# "Aditi Mittal: Things They Wouldn't Let Me Say"

# %%
df101 = df['Time_Min'][df['Title'] == df10]
df101
# Out:
# 312    63
# Name: Time_Min, dtype: int32

# %%
print("The title with longest runtime is", df10,"with a runtime of", df101)
# Out:
# The title with longest runtime is Aditi Mittal: Things They Wouldn't Let Me Say with a runtime of 312    63
# Name: Time_Min, dtype: int32

# %% [markdown]
# #### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
dTV = df[df['Category'] == 'TV Show']

# %%
dTV.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_Y    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#    Time_Min
# 0         4
# 5         1

# %%
dTV['Country'].value_counts()
# Out:
# United States                                     705
# United Kingdom                                    204
# Japan                                             157
# South Korea                                       147
# India                                              71
#                                                  ...
# United Kingdom, Germany, United States, France      1
# United States, Mexico, Spain, Malta                 1
# United Arab Emirates                                1
# United States, France, Canada                       1
# Taiwan, Malaysia                                    1
# Name: Country, Length: 183, dtype: int64

# %%
dTV['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# #### Q. 12) How can we sort the dataset by Year ?

# %%
df.sort_values(by='Year', ascending = False).head(5)
# Out:
#      Show_Id Category              Title                      Director  \
# 7353   s7352    Movie            Unknown            Jaume Collet-Serra
# 2013   s2014    Movie   Enter the Dragon                 Robert Clouse
# 2349   s2350    Movie          Gangaajal                   Prakash Jha
# 1497   s1498    Movie     Cool Hand Luke              Stuart Rosenberg
# 1194   s1195    Movie  Can't Hardly Wait  Harry Elfont, Deborah Kaplan
#
#                                                    Cast  \
# 7353  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
# 2349  Ajay Devgn, Gracy Singh, Mohan Agashe, Mohan J...
# 1497  Paul Newman, George Kennedy, J.D. Cannon, Lou ...
# 1194  Jennifer Love Hewitt, Ethan Embry, Charlie Kor...
#
#                                              Country     Release_Date Rating  \
# 7353  United Kingdom, Germany, France, United States  January 1, 2021  PG-13
# ...

# %% [markdown]
# #### Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df[(((df['Category'] == 'Movie') & df['Type'].str.contains('Drama')) | (df['Category'] == 'TV Show') & (df['Type'].str.contains('Kids')))]
# Out:
#      Show_Id Category        Title           Director  \
# 1         s2    Movie        07:19  Jorge Michel Grau
# 4         s5    Movie           21     Robert Luketic
# 7         s8    Movie          187     Kevin Reynolds
# 10       s11    Movie         1922       Zak Hilditch
# 15       s16    Movie       Oct-01     Kunle Afolayan
# ...      ...      ...          ...                ...
# 7778   s7777    Movie     Zokkomon   Satyajit Bhatkal
# 7779   s7778  TV Show  Zombie Dumb                NaN
# 7782   s7781    Movie          Zoo       Shlok Sharma
# 7784   s7783    Movie         Zozo        Josef Fares
# 7785   s7784    Movie       Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...

# %% [markdown]
# ##### We have successfully analyzed the Netflix dataset and answered about 13 of the questions we had from this dataset.

# %% [markdown]
# ### The End
